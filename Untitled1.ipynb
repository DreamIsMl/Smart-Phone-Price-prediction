# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('flipkart_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                               product  ram  rom  \
# 0           0    REDMI 10 (Caribbean Green, 128 GB)    6    1
# 1           1       POCO C55 (Forest Green, 128 GB)    6    1
# 2           2        REDMI 10 (Shadow Black, 64 GB)    4    6
# 3           3  MOTOROLA g13 (Lavender Blue, 128 GB)    4    1
# 4           4     MOTOROLA e32 (Arctic Blue, 64 GB)    4    6
#
#   expandable memory                  camera front camera  rating   price
# 0              1 TB             50MP + 2MP           5MP     4.2  10,999
# 1              1 TB  50MP Dual Rear Camera           5MP     4.1   8,999
# 2              1 TB             50MP + 2MP           5MP     4.3   9,499
# 3              1 TB       50MP + 2MP + 2MP           8MP     3.9   9,999
# 4              1 TB             50MP + 2MP           8MP     3.9   7,999

# %%
df.shape
# Out:
# (960, 9)

# %%
df['product'] = df['product'].apply(lambda x:" ".join(x.split()[0:2]))

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating   price
# 0             50MP + 2MP           5MP     4.2  10,999
# 1  50MP Dual Rear Camera           5MP     4.1   8,999
# 2             50MP + 2MP           5MP     4.3   9,499
# 3       50MP + 2MP + 2MP           8MP     3.9   9,999
# 4             50MP + 2MP           8MP     3.9   7,999

# %%
df['price'] = df['price'].str.replace(',','')
df['price'] = df['price'].astype('int')

# %%
plt.figure(figsize=(20,8))
sns.barplot(x=df['product'],y =df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x=df['product'],y =df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# product               object
# ram                    int64
# rom                    int64
# expandable memory     object
# camera                object
# front camera          object
# rating               float64
# price                  int32
# dtype: object

# %%
df.price.value_counts()
# Out:
# price
# 16999    35
# 9999     30
# 10999    29
# 15999    26
# 23999    25
#          ..
# 9995      1
# 5222      1
# 29988     1
# 34468     1
# 28900     1
# Name: count, Length: 314, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['ram'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['ram'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['rom'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['rom'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['expandable memory'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['camera'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
df.describe()
# Out:
#        Unnamed: 0         ram         rom      rating          price
# count  960.000000  960.000000  960.000000  960.000000     960.000000
# mean   479.500000    6.327083    2.709375    4.239167   20590.221875
# std    277.272429    5.477349    2.225531    0.208843   18385.489871
# min      0.000000    1.000000    0.000000    3.000000    3599.000000
# 25%    239.750000    4.000000    1.000000    4.200000    9999.000000
# 50%    479.500000    6.000000    1.000000    4.200000   15094.000000
# 75%    719.250000    8.000000    6.000000    4.400000   23999.000000
# max    959.000000   64.000000    8.000000    5.000000  129999.000000

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df['rating'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
# df['expandable memory'] = df['expandable memory'].str.replace('TB','')
# df['expandable memory'] = df['expandable memory'].str.replace('Not Applicable','Not Define')

# # df['expandable memory'] = df['expandable memory'].astype('int')

# %%
# df['expandable memory'] = df['expandable memory'].replace('', None)

# %%
# df['expandable memory'].unique()

# %%
# df['expandable memory'] = df['expandable memory'].str.replace('GB','')

# %%
# df['expandable memory'] = df['expandable memory'].str.replace('MB','')

# %%
# df['expandable memory'] = df['expandable memory'].astype(float)

# %%
# df['expandable memory'] = df['expandable memory'].fillna(df['expandable memory'].median())

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# product                0
# ram                    0
# rom                    0
# expandable memory      0
# camera                 0
# front camera         214
# rating                 0
# price                  0
# dtype: int64

# %%
df['front camera'].value_counts()
# Out:
# front camera
#  16M    197
#  8MP    189
#  5MP    150
#  32M     57
#  13M     49
#  12M     48
#  50M     14
#  20M     12
#  2MP     10
#  44M      7
# 10        5
#  10M      4
# 60        2
#  60M      2
# Name: count, dtype: int64

# %%
df['front camera'] = df['front camera'].fillna('8MP')

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# product              0
# ram                  0
# rom                  0
# expandable memory    0
# camera               0
# front camera         0
# rating               0
# price                0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0         ram         rom      rating          price
# count  960.000000  960.000000  960.000000  960.000000     960.000000
# mean   479.500000    6.327083    2.709375    4.239167   20590.221875
# std    277.272429    5.477349    2.225531    0.208843   18385.489871
# min      0.000000    1.000000    0.000000    3.000000    3599.000000
# 25%    239.750000    4.000000    1.000000    4.200000    9999.000000
# 50%    479.500000    6.000000    1.000000    4.200000   15094.000000
# 75%    719.250000    8.000000    6.000000    4.400000   23999.000000
# max    959.000000   64.000000    8.000000    5.000000  129999.000000

# %%
import numpy as np

mean = df['ram'].mean()
std_dev = df['ram'].std()

df1 = df[(df['ram'] >= mean - std_dev) & (df['ram'] <= mean + std_dev)]

print(df1.shape)
print(df.shape)
# Out:
# (882, 9)
# (960, 9)

# %%
df1.describe()
# Out:
#        Unnamed: 0         ram         rom      rating          price
# count  882.000000  882.000000  882.000000  882.000000     882.000000
# mean   473.863946    5.384354    2.865079    4.221655   16936.219955
# std    276.871126    2.116554    2.238083    0.188718   11257.009556
# min      0.000000    1.000000    1.000000    3.300000    3599.000000
# 25%    237.250000    4.000000    1.000000    4.100000    9999.000000
# 50%    471.500000    6.000000    1.000000    4.200000   14100.000000
# 75%    713.750000    8.000000    6.000000    4.300000   19999.000000
# max    959.000000    8.000000    8.000000    5.000000  104999.000000

# %%
df.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
import numpy as np

mean = df['price'].mean()
std_dev = df['price'].std()

df2 = df[(df['price'] >= mean - std_dev) & (df['price'] <= mean + std_dev)]

print(df1.shape)
print(df2.shape)
# Out:
# (882, 9)
# (868, 9)

# %%
df2.head()
# Out:
#    Unnamed: 0       product  ram  rom expandable memory  \
# 0           0      REDMI 10    6    1              1 TB
# 1           1      POCO C55    6    1              1 TB
# 2           2      REDMI 10    4    6              1 TB
# 3           3  MOTOROLA g13    4    1              1 TB
# 4           4  MOTOROLA e32    4    6              1 TB
#
#                    camera front camera  rating  price
# 0             50MP + 2MP           5MP     4.2  10999
# 1  50MP Dual Rear Camera           5MP     4.1   8999
# 2             50MP + 2MP           5MP     4.3   9499
# 3       50MP + 2MP + 2MP           8MP     3.9   9999
# 4             50MP + 2MP           8MP     3.9   7999

# %%
sns.displot(np.log(df['price']))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
df2.drop(['Unnamed: 0'],axis=1,inplace=True)
# Out:
# C:\Users\Ghost Codm\AppData\Local\Temp\ipykernel_2880\2760647796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
x = df2.drop(['price'],axis=1)
y  = np.log(df2['price'])

# %%
from sklearn.model_selection import train_test_split,cross_val_score
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.2,random_state=6)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
xtrain.dtypes
# Out:
# product               object
# ram                    int64
# rom                    int64
# expandable memory     object
# camera                object
# front camera          object
# rating               float64
# dtype: object

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0,3,4,5])
], remainder='passthrough')
step2 = LinearRegression()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores: ',r2_score(ytest,y_pred))
print('MAE', mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# r2 scores:  -1.4642858011847117e+19
# MAE 332597590.9670018

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0,3,4,5])
], remainder='passthrough')
step2 = XGBRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores: ',r2_score(ytest,y_pred))
print('MAE', mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# r2 scores:  0.9266871891490902
# MAE 0.08633496916931829
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0,3,4,5])
], remainder='passthrough')
step2 = BaggingRegressor(base_estimator=XGBRegressor(),
                        n_estimators=100)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores: ',r2_score(ytest,y_pred))
print('MAE', mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0,3,4,5])
], remainder='passthrough')
step2 = RandomForestRegressor()
pipe2 = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe2.fit(xtrain,ytrain)
y_pred = pipe2.predict(xtest)
print('r2 scores: ',r2_score(ytest,y_pred))
print('MAE', mean_absolute_error(ytest,y_pred))
# scores = cross_val_score(pipe,xtrain,ytrain,cv=5)
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 scores:  0.9352365673760606
# MAE 0.0816319221802761
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# 0.9382744956827365

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0,3,4,5])
], remainder='passthrough')
step2 = DecisionTreeRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores: ',r2_score(ytest,y_pred))
print('MAE', mean_absolute_error(ytest,y_pred))
# Out:
# r2 scores:  0.917022614387463
# MAE 0.07314297097825342
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pickle
pickle.dump(xtrain,open('xtrain.pkl','wb'))
pickle.dump(pipe2,open('smodel.pkl','wb'))

# %%
xtrain
# Out:
#             product  ram  rom expandable memory                    camera  \
# 759  SAMSUNG Galaxy    8    1    Not Applicable          12MP Rear Camera
# 404      REDMI Note    6    1              2 GB   64MP + 8MP + 2MP + 2MP
# 623         vivo T1    6    1    Not Applicable         64MP + 8MP + 2MP
# 729     Infinix Hot    4    6              1 TB  13 MP + 2 MP Depth Lens
# 750      REDMI NOTE    6    1    Not Applicable          48MP Rear Camera
# ..              ...  ...  ...               ...                       ...
# 356    realme Narzo    4    1              6 GB         50MP + 2MP + 2MP
# 387       itel A23S    2    3    Not Applicable           2MP Rear Camera
# 659        vivo Y02    3    3    Not Applicable          8MP Rear Camera
# 245         vivo T1    6    1              1 TB         50MP + 2MP + 2MP
# 763         POCO X2    8    2              2 GB   64MP + 8MP + 2MP + 2MP
#
#     front camera  rating
# 759          8MP     4.2
# 404          13M     4.4
# ...
